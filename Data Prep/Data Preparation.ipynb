# %% [markdown]
# # Importing packages and libraries

# %%
# For those who have not installed these libraries before
# !pip install category_encoders
# !pip install imbalanced-learn

# %%
# Packages for data manipulation
import pandas as pd
import numpy as np

# Packages for visualisation
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import OneHotEncoder

# Packages for modelling
from sklearn.preprocessing import MinMaxScaler
# from category_encoders import TargetEncoder

from sklearn.decomposition import PCA
from sklearn.feature_selection import chi2

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # Reading data

# %%
data = pd.read_csv("../Data/BankChurners.csv")
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
# 3              34  ...        3313.0                 2517            796.0
# 4              21  ...        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio  \
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
#
# [5 rows x 23 columns]

# %% [markdown]
# # Dropping irrelevant columns

# %%
data.drop(columns=["CLIENTNUM", "Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1", "Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2"], axis=1, inplace=True)

data.head()
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         5                       1                      3
# 1                         6                       1                      2
# 2                         4                       1                      0
# 3                         3                       4                      1
# 4                         5                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000

# %% [markdown]
# # Dropping columns with correlation > 0.7
# - Some variables have very high correlation while some have mild correlation
# - Only 1 of the variables were kept for pairs of variables which have correlation value > 0.7 to avoid multicollinearity
#
# ** Can explore using VIF

# %%
data.corr(method='pearson')[(data.corr() > 0.2) & (data.corr() != 1)]

# i think this one is pre-determined in EDA, so dunnid to show here
# Out:
#                           Customer_Age  Dependent_count  Months_on_book  \
# Customer_Age                       NaN              NaN        0.788912
# Dependent_count                    NaN              NaN             NaN
# Months_on_book                0.788912              NaN             NaN
# Total_Relationship_Count           NaN              NaN             NaN
# Months_Inactive_12_mon             NaN              NaN             NaN
# Contacts_Count_12_mon              NaN              NaN             NaN
# Credit_Limit                       NaN              NaN             NaN
# Total_Revolving_Bal                NaN              NaN             NaN
# Avg_Open_To_Buy                    NaN              NaN             NaN
# Total_Amt_Chng_Q4_Q1               NaN              NaN             NaN
# Total_Trans_Amt                    NaN              NaN             NaN
# Total_Trans_Ct                     NaN              NaN             NaN
# Total_Ct_Chng_Q4_Q1                NaN              NaN             NaN
# Avg_Utilization_Ratio              NaN              NaN             NaN
#
#                           Total_Relationship_Count  Months_Inactive_12_mon  \
# Customer_Age                                   NaN                     NaN
# Dependent_count                                NaN                     NaN
# Months_on_book                                 NaN                     NaN
# Total_Relationship_Count                       NaN                     NaN
# Months_Inactive_12_mon                         NaN                     NaN
# Contacts_Count_12_mon                          NaN                     NaN
# Credit_Limit                                   NaN                     NaN
# Total_Revolving_Bal                            NaN                     NaN
# Avg_Open_To_Buy                                NaN                     NaN
# Total_Amt_Chng_Q4_Q1                           NaN                     NaN
# Total_Trans_Amt                                NaN                     NaN
# Total_Trans_Ct                                 NaN                     NaN
# Total_Ct_Chng_Q4_Q1                            NaN                     NaN
# Avg_Utilization_Ratio                          NaN                     NaN
#
#                           Contacts_Count_12_mon  Credit_Limit  \
# Customer_Age                                NaN           NaN
# Dependent_count                             NaN           NaN
# Months_on_book                              NaN           NaN
# Total_Relationship_Count                    NaN           NaN
# Months_Inactive_12_mon                      NaN           NaN
# Contacts_Count_12_mon                       NaN           NaN
# Credit_Limit                                NaN           NaN
# Total_Revolving_Bal                         NaN           NaN
# Avg_Open_To_Buy                             NaN      0.995981
# Total_Amt_Chng_Q4_Q1                        NaN           NaN
# Total_Trans_Amt                             NaN           NaN
# Total_Trans_Ct                              NaN           NaN
# Total_Ct_Chng_Q4_Q1                         NaN           NaN
# Avg_Utilization_Ratio                       NaN           NaN
#
#                           Total_Revolving_Bal  Avg_Open_To_Buy  \
# Customer_Age                              NaN              NaN
# Dependent_count                           NaN              NaN
# Months_on_book                            NaN              NaN
# Total_Relationship_Count                  NaN              NaN
# Months_Inactive_12_mon                    NaN              NaN
# Contacts_Count_12_mon                     NaN              NaN
# Credit_Limit                              NaN         0.995981
# Total_Revolving_Bal                       NaN              NaN
# Avg_Open_To_Buy                           NaN              NaN
# Total_Amt_Chng_Q4_Q1                      NaN              NaN
# Total_Trans_Amt                           NaN              NaN
# Total_Trans_Ct                            NaN              NaN
# Total_Ct_Chng_Q4_Q1                       NaN              NaN
# Avg_Utilization_Ratio                0.624022              NaN
#
#                           Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# Customer_Age                               NaN              NaN
# Dependent_count                            NaN              NaN
# Months_on_book                             NaN              NaN
# Total_Relationship_Count                   NaN              NaN
# Months_Inactive_12_mon                     NaN              NaN
# Contacts_Count_12_mon                      NaN              NaN
# Credit_Limit                               NaN              NaN
# Total_Revolving_Bal                        NaN              NaN
# Avg_Open_To_Buy                            NaN              NaN
# Total_Amt_Chng_Q4_Q1                       NaN              NaN
# Total_Trans_Amt                            NaN              NaN
# Total_Trans_Ct                             NaN         0.807192
# Total_Ct_Chng_Q4_Q1                   0.384189              NaN
# Avg_Utilization_Ratio                      NaN              NaN
#
#                           Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# Customer_Age                         NaN                  NaN
# Dependent_count                      NaN                  NaN
# Months_on_book                       NaN                  NaN
# Total_Relationship_Count             NaN                  NaN
# Months_Inactive_12_mon               NaN                  NaN
# Contacts_Count_12_mon                NaN                  NaN
# Credit_Limit                         NaN                  NaN
# Total_Revolving_Bal                  NaN                  NaN
# Avg_Open_To_Buy                      NaN                  NaN
# Total_Amt_Chng_Q4_Q1                 NaN             0.384189
# Total_Trans_Amt                 0.807192                  NaN
# Total_Trans_Ct                       NaN                  NaN
# Total_Ct_Chng_Q4_Q1                  NaN                  NaN
# Avg_Utilization_Ratio                NaN                  NaN
#
#                           Avg_Utilization_Ratio
# Customer_Age                                NaN
# Dependent_count                             NaN
# Months_on_book                              NaN
# Total_Relationship_Count                    NaN
# Months_Inactive_12_mon                      NaN
# Contacts_Count_12_mon                       NaN
# Credit_Limit                                NaN
# Total_Revolving_Bal                    0.624022
# Avg_Open_To_Buy                             NaN
# Total_Amt_Chng_Q4_Q1                        NaN
# Total_Trans_Amt                             NaN
# Total_Trans_Ct                              NaN
# Total_Ct_Chng_Q4_Q1                         NaN
# Avg_Utilization_Ratio                       NaN

# %%
data_dropped = data.drop(columns=["Customer_Age", "Avg_Open_To_Buy", "Total_Trans_Ct"])
data_dropped.head()
# Out:
#       Attrition_Flag Gender  Dependent_count Education_Level Marital_Status  \
# 0  Existing Customer      M                3     High School        Married
# 1  Existing Customer      F                5        Graduate         Single
# 2  Existing Customer      M                3        Graduate        Married
# 3  Existing Customer      F                4     High School        Unknown
# 4  Existing Customer      M                3      Uneducated        Married
#
#   Income_Category Card_Category  Months_on_book  Total_Relationship_Count  \
# 0     $60K - $80K          Blue              39                         5
# 1  Less than $40K          Blue              44                         6
# 2    $80K - $120K          Blue              36                         4
# 3  Less than $40K          Blue              34                         3
# 4     $60K - $80K          Blue              21                         5
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 0                       1                      3       12691.0
# 1                       1                      2        8256.0
# 2                       1                      0        3418.0
# 3                       4                      1        3313.0
# 4                       1                      0        4716.0
#
#    Total_Revolving_Bal  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# 0                  777                 1.335             1144
# 1                  864                 1.541             1291
# 2                    0                 2.594             1887
# 3                 2517                 1.405             1171
# 4                    0                 2.175              816
#
#    Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0                1.625                  0.061
# 1                3.714                  0.105
# 2                2.333                  0.000
# 3                2.333                  0.760
# 4                2.500                  0.000

# %% [markdown]
# # Renaming columns

# %%
data_dropped.columns = ['attrition_flag', 'gender', 'dependent_count', 'education_level', 'marital_status', 'income_category', 'card_category', 'months_on_book', 'total_relationship_count', 'months_inactive_12_month', 'contacts_count_12_month', 'credit_limit', 'total_revolving_bal', 'total_amt_change_q4_q1', 'total_trans_amt', 'total_count_change_q4_q1', 'avg_utilization_ratio']

# %% [markdown]
# # Splitting into numerical and categorical columns

# %%
# Determine numerical columns
numerical_cols = list(data_dropped.describe().columns)

# Determine categorical columns
categorical_cols = [i for i in data_dropped.columns if i not in numerical_cols and i != "Attrition_Flag"]

print(f"Numerical Columns:\n{numerical_cols}\n")
print(f"Categorical Columns:\n{categorical_cols}")
# Out:
# Numerical Columns:
# ['dependent_count', 'months_on_book', 'total_relationship_count', 'months_inactive_12_month', 'contacts_count_12_month', 'credit_limit', 'total_revolving_bal', 'total_amt_change_q4_q1', 'total_trans_amt', 'total_count_change_q4_q1', 'avg_utilization_ratio']
#
# Categorical Columns:
# ['attrition_flag', 'gender', 'education_level', 'marital_status', 'income_category', 'card_category']

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Log transformation for skewed variables

# %%
data_dropped[numerical_cols].skew()[(data_dropped[numerical_cols].skew() > 1) | (data_dropped[numerical_cols].skew() < -1)]
# Out:
# credit_limit                1.666726
# total_amt_change_q4_q1      1.732063
# total_trans_amt             2.041003
# total_count_change_q4_q1    2.064031
# dtype: float64

# %%
data_log = data_dropped
for skewed_col in ["credit_limit", "total_amt_change_q4_q1", "total_trans_amt", "total_count_change_q4_q1"]:
    data_log[skewed_col]= np.where(data_log[skewed_col] > 0 , np.log(data_log[skewed_col]), 0)
data_log.head()

# Jon: I did this prev in my own log transformation! Just storing here in case need
# skewed_cols = []

# for num in numerical_cols:
#     if df[num].skew() < -1 or df[num].skew() > 1:
#         skewed_cols.append(num)
# print(skewed_cols)

# for col in skewed_cols:
#     df[col] = np.log(df[col].mask(df[col] <=0)).fillna(0)

# df.head()
# Out:
# /Users/jonw/miniforge3/envs/ml_env/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#       attrition_flag gender  dependent_count education_level marital_status  \
# 0  Existing Customer      M                3     High School        Married
# 1  Existing Customer      F                5        Graduate         Single
# 2  Existing Customer      M                3        Graduate        Married
# 3  Existing Customer      F                4     High School        Unknown
# 4  Existing Customer      M                3      Uneducated        Married
#
#   income_category card_category  months_on_book  total_relationship_count  \
# 0     $60K - $80K          Blue              39                         5
# 1  Less than $40K          Blue              44                         6
# 2    $80K - $120K          Blue              36                         4
# 3  Less than $40K          Blue              34                         3
# 4     $60K - $80K          Blue              21                         5
#
#    months_inactive_12_month  contacts_count_12_month  credit_limit  \
# 0                         1                        3      9.448648
# 1                         1                        2      9.018695
# 2                         1                        0      8.136811
# 3                         4                        1      8.105609
# 4                         1                        0      8.458716
#
#    total_revolving_bal  total_amt_change_q4_q1  total_trans_amt  \
# 0                  777                0.288931         7.042286
# 1                  864                0.432432         7.163172
# 2                    0                0.953201         7.542744
# 3                 2517                0.340037         7.065613
# 4                    0                0.777029         6.704414
#
#    total_count_change_q4_q1  avg_utilization_ratio
# 0                  0.485508                  0.061
# 1                  1.312109                  0.105
# 2                  0.847155                  0.000
# 3                  0.847155                  0.760
# 4                  0.916291                  0.000

# %%
data_log[numerical_cols].skew()
# Out:
# dependent_count            -0.020826
# months_on_book             -0.106565
# total_relationship_count   -0.162452
# months_inactive_12_month    0.633061
# contacts_count_12_month     0.011006
# credit_limit                0.457081
# total_revolving_bal        -0.148837
# total_amt_change_q4_q1     -1.024660
# total_trans_amt             0.262210
# total_count_change_q4_q1   -1.125235
# avg_utilization_ratio       0.718008
# dtype: float64

# %% [markdown]
# # Scaling columns using normalisation
# - To transform the data points to range (0,1)

# %%
# plt.rcParams['figure.figsize'] = 5,5
# data_log[numerical_cols].boxplot(rot=90)

# %%
data_scaled = data_log
scaler = MinMaxScaler()

data_scaled[numerical_cols] = scaler.fit_transform(data_log[numerical_cols])

# %%
# plt.rcParams['figure.figsize'] = 5,5
# data_scaled[numerical_cols].boxplot(rot=90)

# %%
data_scaled.head()
# Out:
#       attrition_flag gender  dependent_count education_level marital_status  \
# 0  Existing Customer      M              0.6     High School        Married
# 1  Existing Customer      F              1.0        Graduate         Single
# 2  Existing Customer      M              0.6        Graduate        Married
# 3  Existing Customer      F              0.8     High School        Unknown
# 4  Existing Customer      M              0.6      Uneducated        Married
#
#   income_category card_category  months_on_book  total_relationship_count  \
# 0     $60K - $80K          Blue        0.604651                       0.8
# 1  Less than $40K          Blue        0.720930                       1.0
# 2    $80K - $120K          Blue        0.534884                       0.6
# 3  Less than $40K          Blue        0.488372                       0.4
# 4     $60K - $80K          Blue        0.186047                       0.8
#
#    months_inactive_12_month  contacts_count_12_month  credit_limit  \
# 0                  0.166667                 0.500000      0.685166
# 1                  0.166667                 0.333333      0.549874
# 2                  0.166667                 0.000000      0.272374
# 3                  0.666667                 0.166667      0.262556
# 4                  0.166667                 0.000000      0.373667
#
#    total_revolving_bal  total_amt_change_q4_q1  total_trans_amt  \
# 0             0.308701                0.839748         0.225019
# 1             0.343266                0.864370         0.258690
# 2             0.000000                0.953725         0.364413
# 3             1.000000                0.848516         0.231517
# 4             0.000000                0.923497         0.130911
#
#    total_count_change_q4_q1  avg_utilization_ratio
# 0                  0.830880               0.061061
# 1                  1.000000               0.105105
# 2                  0.904872               0.000000
# 3                  0.904872               0.760761
# 4                  0.919017               0.000000

# %% [markdown]
# ## Encoding categorical columns
# - Converting categorical columns to numeric values for better fitting to the model
# - attrition_flag -> nominal, binary
# - gender -> nominal, binary
# - education_level -> ordinal
# - marital_status -> nominal
# - income_category -> ordinal
# - card_category -> ordinal

# %%
# Jon: I think these should be inside the EDA notebook?
# Visualising categorical columns 
# fig, axes = plt.subplots(nrows = 2, ncols=3)
# plt.rcParams['figure.figsize'] = 10, 10

# data["Attrition_Flag"].value_counts().plot.bar(ax=axes[0,0], rot=30)
# data["Gender"].value_counts().plot.bar(ax=axes[0,1], rot=30)
# data["Education_Level"].value_counts().plot.bar(ax=axes[0,2], rot=30)
# data["Marital_Status"].value_counts().plot.bar(ax=axes[1,0], rot=30)
# data["Income_Category"].value_counts().plot.bar(ax=axes[1,1], rot=30)
# data["Card_Category"].value_counts().plot.bar(ax=axes[1,2], rot=30)

# %%
# # drop_first: features that only require one column during one hot encoding will use only one. 
# # Rationale: to reduce dimensions further and prevent collinearity between 2 parameters
# features_onehotencoded = pd.get_dummies(data[categorical_cols], drop_first=True)

# # Comparison of what categorical columns:
# print("Number of categorical columns before encoding:", len(categorical_cols))
# print("Number of categorical columns after encoding:", len(features_onehotencoded.columns))

# # Combine numerical columns back
# processed_features = pd.concat([features_onehotencoded, data_scaled[numerical_cols]], axis = 1)

# # Comparison of what columns changed:
# print("\nAll features before encoding:\n" + str(list(data.columns)[1:])) # Don't display target variable
# print("\nAll features after encoding:\n" + str(list(processed_features.columns)))

# processed_features.head()

# %% [markdown]
# ### Label Encoding `attrition_flag`, `gender`

# %%
label_encoded = pd.get_dummies(data_scaled[["attrition_flag", "gender"]], drop_first=True)
label_encoded.rename(columns={"attrition_flag_Existing Customer": "attrition_flag", "gender_M": "gender"}, inplace=True)

data_scaled.drop(columns=["attrition_flag", "gender"], inplace=True)
data_scaled = pd.concat([label_encoded, data_scaled], axis=1)

data_scaled.head()
# Out:
#    attrition_flag  gender  dependent_count education_level marital_status  \
# 0               1       1              0.6     High School        Married
# 1               1       0              1.0        Graduate         Single
# 2               1       1              0.6        Graduate        Married
# 3               1       0              0.8     High School        Unknown
# 4               1       1              0.6      Uneducated        Married
#
#   income_category card_category  months_on_book  total_relationship_count  \
# 0     $60K - $80K          Blue        0.604651                       0.8
# 1  Less than $40K          Blue        0.720930                       1.0
# 2    $80K - $120K          Blue        0.534884                       0.6
# 3  Less than $40K          Blue        0.488372                       0.4
# 4     $60K - $80K          Blue        0.186047                       0.8
#
#    months_inactive_12_month  contacts_count_12_month  credit_limit  \
# 0                  0.166667                 0.500000      0.685166
# 1                  0.166667                 0.333333      0.549874
# 2                  0.166667                 0.000000      0.272374
# 3                  0.666667                 0.166667      0.262556
# 4                  0.166667                 0.000000      0.373667
#
#    total_revolving_bal  total_amt_change_q4_q1  total_trans_amt  \
# 0             0.308701                0.839748         0.225019
# 1             0.343266                0.864370         0.258690
# 2             0.000000                0.953725         0.364413
# 3             1.000000                0.848516         0.231517
# 4             0.000000                0.923497         0.130911
#
#    total_count_change_q4_q1  avg_utilization_ratio
# 0                  0.830880               0.061061
# 1                  1.000000               0.105105
# 2                  0.904872               0.000000
# 3                  0.904872               0.760761
# 4                  0.919017               0.000000

# %% [markdown]
# ### OneHotEncoding `marital_status`

# %%
# Might need to find other ways to encode because not very correct way
onehot_enc = OneHotEncoder()
reshape = np.array(data_scaled["marital_status"]).reshape(-1, 1)
values = onehot_enc.fit_transform(reshape).toarray().astype(int)
labels = np.array(["divorced", "married", "single", "unknown_marital_status"]).ravel()
marital_status_df = pd.DataFrame(values, columns=labels)

data_scaled = data_scaled.join(marital_status_df["divorced"])
data_scaled = data_scaled.join(marital_status_df["married"])
data_scaled = data_scaled.join(marital_status_df["single"])
data_scaled = data_scaled.join(marital_status_df["unknown_marital_status"])

data_scaled.drop("marital_status", axis=1, inplace=True)

data_scaled.head()
# Out:
#    attrition_flag  gender  dependent_count education_level income_category  \
# 0               1       1              0.6     High School     $60K - $80K
# 1               1       0              1.0        Graduate  Less than $40K
# 2               1       1              0.6        Graduate    $80K - $120K
# 3               1       0              0.8     High School  Less than $40K
# 4               1       1              0.6      Uneducated     $60K - $80K
#
#   card_category  months_on_book  total_relationship_count  \
# 0          Blue        0.604651                       0.8
# 1          Blue        0.720930                       1.0
# 2          Blue        0.534884                       0.6
# 3          Blue        0.488372                       0.4
# 4          Blue        0.186047                       0.8
#
#    months_inactive_12_month  contacts_count_12_month  credit_limit  \
# 0                  0.166667                 0.500000      0.685166
# 1                  0.166667                 0.333333      0.549874
# 2                  0.166667                 0.000000      0.272374
# 3                  0.666667                 0.166667      0.262556
# 4                  0.166667                 0.000000      0.373667
#
#    total_revolving_bal  total_amt_change_q4_q1  total_trans_amt  \
# 0             0.308701                0.839748         0.225019
# 1             0.343266                0.864370         0.258690
# 2             0.000000                0.953725         0.364413
# 3             1.000000                0.848516         0.231517
# 4             0.000000                0.923497         0.130911
#
#    total_count_change_q4_q1  avg_utilization_ratio  divorced  married  single  \
# 0                  0.830880               0.061061         0        1       0
# 1                  1.000000               0.105105         0        0       1
# 2                  0.904872               0.000000         0        1       0
# 3                  0.904872               0.760761         0        0       0
# 4                  0.919017               0.000000         0        1       0
#
#    unknown_marital_status
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0

# %% [markdown]
# ### Ordinal Encoding: `education_level`, `income_category`, `card_category`

# %%
edu_level_mapper = {"Doctorate": 7, "Post-Graduate": 6, "Graduate": 5, "College": 4, "High School": 3, "Uneducated": 2, "Unknown": 1}
data_scaled["education_level"] = data_scaled["education_level"].replace(edu_level_mapper)

income_cat_mapper = {"$120K +": 6, "$80K - $120K": 5, "$60K - $80K": 4, "$40K - $60K": 3, "Less than $40K": 2, "Unknown": 1}
data_scaled["income_category"] = data_scaled["income_category"].replace(income_cat_mapper)

card_cat_mapper = {"Platinum": 4, "Gold": 3, "Silver": 2, "Blue": 1}
data_scaled["card_category"] = data_scaled["card_category"].replace(card_cat_mapper)

data_scaled.head()
# Out:
#    attrition_flag  gender  dependent_count  education_level  income_category  \
# 0               1       1              0.6                3                4
# 1               1       0              1.0                5                2
# 2               1       1              0.6                5                5
# 3               1       0              0.8                3                2
# 4               1       1              0.6                2                4
#
#    card_category  months_on_book  total_relationship_count  \
# 0              1        0.604651                       0.8
# 1              1        0.720930                       1.0
# 2              1        0.534884                       0.6
# 3              1        0.488372                       0.4
# 4              1        0.186047                       0.8
#
#    months_inactive_12_month  contacts_count_12_month  credit_limit  \
# 0                  0.166667                 0.500000      0.685166
# 1                  0.166667                 0.333333      0.549874
# 2                  0.166667                 0.000000      0.272374
# 3                  0.666667                 0.166667      0.262556
# 4                  0.166667                 0.000000      0.373667
#
#    total_revolving_bal  total_amt_change_q4_q1  total_trans_amt  \
# 0             0.308701                0.839748         0.225019
# 1             0.343266                0.864370         0.258690
# 2             0.000000                0.953725         0.364413
# 3             1.000000                0.848516         0.231517
# 4             0.000000                0.923497         0.130911
#
#    total_count_change_q4_q1  avg_utilization_ratio  divorced  married  single  \
# 0                  0.830880               0.061061         0        1       0
# 1                  1.000000               0.105105         0        0       1
# 2                  0.904872               0.000000         0        1       0
# 3                  0.904872               0.760761         0        0       0
# 4                  0.919017               0.000000         0        1       0
#
#    unknown_marital_status
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0

# %% [markdown]
# # Creating Train, Validation, Test sets
#
# ## Use stratify to ensure the percentage of each class remains the same throughout the split

# %%
y = data_scaled["attrition_flag"]
X = data_scaled.drop(columns="attrition_flag", axis=1)

# Split dataset into training and test subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2021, stratify=y)
print("Ratio for training + validation set\n", y_train.value_counts(normalize=True), "\n")
print("Ratio for test set\n", y_test.value_counts(normalize=True))

# # Split training dataset into training and validation subsets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=2021, stratify=y_train)
print("Ratio for training set\n", y_train.value_counts(normalize=True), "\n")
print("Ratio for cal set\n", y_test.value_counts(normalize=True))
# Out:
# Ratio for training + validation set
#  1    0.839279
# 0    0.160721
# Name: attrition_flag, dtype: float64
#
# Ratio for test set
#  1    0.839585
# 0    0.160415
# Name: attrition_flag, dtype: float64
# Ratio for training set
#  1    0.839342
# 0    0.160658
# Name: attrition_flag, dtype: float64
#
# Ratio for cal set
#  1    0.839585
# 0    0.160415
# Name: attrition_flag, dtype: float64

# %%
print(len(data))
print("Train size:", len(X_train))
print("Validation size:", len(X_val))
print("Test size:", len(X_test))
print("Total:", len(X_train) + len(X_val) + len(X_test))
# Out:
# 10127
# Train size: 6075
# Validation size: 2026
# Test size: 2026
# Total: 10127

# %% [markdown]
# ## Perform oversampling on minority class ("Attrited") for training set

# %%
oversampler = SMOTE()
X_train, y_train = oversampler.fit_resample(X_train, y_train)
y_train.value_counts()
# Out:
# 1    5099
# 0    5099
# Name: attrition_flag, dtype: int64

# %%
y_train
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 10193    0
# 10194    0
# 10195    0
# 10196    0
# 10197    0
# Name: attrition_flag, Length: 10198, dtype: uint8

# %%
print("\nTrain size after over sampling:", len(y_train))
# Out:
# Train size after over sampling: 10198

# %% [markdown]
# # Writing out Train, Validation, Test sets to csv files

# %%
train = pd.concat([X_train, y_train], axis=1)
train.head()
# Out:
#    gender  dependent_count  education_level  income_category  card_category  \
# 0       0              0.8                1                3              1
# 1       0              0.8                1                3              1
# 2       0              0.6                4                3              1
# 3       0              0.4                5                2              1
# 4       0              0.4                5                2              1
#
#    months_on_book  total_relationship_count  months_inactive_12_month  \
# 0        0.418605                       0.8                  0.166667
# 1        0.581395                       0.6                  0.333333
# 2        0.488372                       0.4                  0.166667
# 3        0.534884                       0.6                  0.500000
# 4        0.767442                       0.8                  0.333333
#
#    contacts_count_12_month  credit_limit  total_revolving_bal  \
# 0                 0.333333      0.123262             0.549464
# 1                 0.500000      0.174586             0.000000
# 2                 0.333333      0.257095             0.402463
# 3                 0.500000      0.058833             0.392133
# 4                 0.333333      0.404833             0.655542
#
#    total_amt_change_q4_q1  total_trans_amt  total_count_change_q4_q1  \
# 0                0.723746         0.571438                  0.675667
# 1                0.751884         0.599208                  0.700689
# 2                0.788100         0.640195                  0.696118
# 3                0.768042         0.620189                  0.713148
# 4                0.730922         0.268858                  0.604718
#
#    avg_utilization_ratio  divorced  married  single  unknown_marital_status  \
# 0               0.650651         0        0       1                       0
# 1               0.000000         0        0       0                       1
# 2               0.311311         0        1       0                       0
# 3               0.569570         1        0       0                       0
# 4               0.317317         0        1       0                       0
#
#    attrition_flag
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
val = pd.concat([X_val, y_val], axis=1)
val.head()
# Out:
#       gender  dependent_count  education_level  income_category  \
# 4922       1              0.8                3                5
# 9826       0              0.6                4                2
# 3447       1              0.4                2                3
# 5523       0              0.6                3                2
# 4223       0              0.6                4                1
#
#       card_category  months_on_book  total_relationship_count  \
# 4922              1        0.534884                       1.0
# 9826              1        0.465116                       0.6
# 3447              1        0.744186                       0.4
# 5523              1        0.651163                       0.4
# 4223              1        0.534884                       0.6
#
#       months_inactive_12_month  contacts_count_12_month  credit_limit  \
# 4922                  0.166667                 0.000000      0.122966
# 9826                  0.333333                 0.333333      0.433408
# 3447                  0.166667                 0.500000      0.466336
# 5523                  0.500000                 0.333333      0.022925
# 4223                  0.333333                 0.666667      0.337953
#
#       total_revolving_bal  total_amt_change_q4_q1  total_trans_amt  \
# 4922             0.524831                0.701375         0.492803
# 9826             0.860151                0.749726         0.941269
# 3447             0.564164                0.680913         0.538623
# 5523             0.000000                0.761274         0.420989
# 4223             0.634485                0.736876         0.596527
#
#       total_count_change_q4_q1  avg_utilization_ratio  divorced  married  \
# 4922                  0.731547               0.621622         0        0
# 9826                  0.717796               0.380380         0        0
# 3447                  0.562644               0.224224         1        0
# 5523                  0.487253               0.000000         0        1
# 4223                  0.650828               0.379379         0        0
#
#       single  unknown_marital_status  attrition_flag
# 4922       0                       1               1
# 9826       1                       0               1
# 3447       0                       0               1
# 5523       0                       0               0
# 4223       1                       0               1

# %%
test = pd.concat([X_test, y_test], axis=1)
test.head()
# Out:
#       gender  dependent_count  education_level  income_category  \
# 5107       0              0.6                5                3
# 2519       1              0.2                5                5
# 8231       0              0.2                1                2
# 1955       0              0.8                1                2
# 214        1              0.8                3                3
#
#       card_category  months_on_book  total_relationship_count  \
# 5107              1        0.418605                       1.0
# 2519              1        0.325581                       1.0
# 8231              1        0.674419                       0.0
# 1955              2        0.441860                       1.0
# 214               1        0.534884                       0.8
#
#       months_inactive_12_month  contacts_count_12_month  credit_limit  \
# 5107                  0.500000                 0.666667      0.735639
# 2519                  0.333333                 0.833333      0.915317
# 8231                  0.166667                 0.333333      0.135159
# 1955                  0.500000                 0.333333      0.709675
# 214                   0.500000                 0.333333      0.698920
#
#       total_revolving_bal  total_amt_change_q4_q1  total_trans_amt  \
# 5107             0.000000                0.624601         0.303989
# 2519             0.542312                0.847168         0.418448
# 8231             0.611442                0.760867         0.632296
# 1955             0.549861                0.821598         0.557476
# 214              0.683750                0.773612         0.208984
#
#       total_count_change_q4_q1  avg_utilization_ratio  divorced  married  \
# 5107                  0.527017               0.000000         0        1
# 2519                  0.731547               0.052052         0        0
# 8231                  0.726157               0.696697         0        0
# 1955                  0.645912               0.101101         0        0
# 214                   0.790354               0.130130         0        1
#
#       single  unknown_marital_status  attrition_flag
# 5107       0                       0               0
# 2519       1                       0               1
# 8231       0                       1               1
# 1955       1                       0               1
# 214        0                       0               1

# %%
train.to_csv("../Data/train.csv")
val.to_csv("../Data/validation.csv")
test.to_csv("../Data/test.csv")
